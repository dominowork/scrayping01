# %%
from bs4 import BeautifulSoup
import re
import pandas as pd
import requests
import time

# %%
HEADER = {"User-Agent":"Chrome/88.0.4324.182"}

def get_cover_urls(sitemap_url="https://www.magazine-data.com/sitemap/sitemap.xml"):
    """
    表紙情報のurl一覧を取得する関数です。
    Args:
        sitemap_url (str) : サイトマップのurl
    """
    
    res = requests.get(sitemap_url, headers=HEADER)
    soup = BeautifulSoup(res.text, "html.parser")
    
    cover_urls = []

    flag = False
    for url in soup.select("url > loc"):
        if re.search(r"/cover/", url.text): # coverを含むもの処理
            if url.text == "https://www.magazine-data.com/cover/anan.html": # anan以降を取得
                flag = True
            if not flag:
                continue
            else:
                cover_urls.append(url.text)
                
    return cover_urls


def get_magazine_summary(url):
    res = requests.get(url, headers=HEADER)
    soup = BeautifulSoup(res.text, "html.parser")
    
    boxes = soup.select_one("#furoku_box dl")
    datas = {"巻号":[], "モデル":[], "URL":[], "発売日":[]}
    
    # 巻号と雑誌のurlを取得
    for cover in boxes.find_all("dt"):
        if cover.find("a"):
            magazine_url = cover.a.attrs["href"]
        else:
            magazine_url = url
        magazine_id = " ".join([w for w in cover.text.split() if w != "→"][1:])

        datas["巻号"].append(magazine_id)
        datas["URL"].append(magazine_url)

    # モデルと発売日を取得
    for model_data in boxes.select("dd p.model"):
        model, release_date = model_data.text.split("発売日：")
        model = model.split("：")[-1]

        datas["モデル"].append(model)
        datas["発売日"].append(release_date)
        
    df = pd.DataFrame(datas)
    
    # titleから雑誌名を取得
    magazine_name = soup.title.text.split("【表紙】")[0].split()
    if len(magazine_name) == 2:
        name_en, name_ja = magazine_name # 英字の雑誌なら日本語表記を取得
    else:
        name_en = magazine_name[0]
        name_ja = name_en # 日本語の雑誌はそのまま
        
    df["雑誌名"] = name_en
    df["ザッシ名"] = name_ja
    df["年"] = df["発売日"].map(lambda x: int(re.search(r"[0-9]+年", x).group()[:-1]))
    df["月"] = df["発売日"].map(lambda x: int(re.search(r"[0-9]+月", x).group()[:-1]))
    
    return df

# %%
cover_urls = get_cover_urls()

# %%
cover_urls
# Out:
# ['https://www.magazine-data.com/cover/anan.html',
#  'https://www.magazine-data.com/cover/nonno.html',
#  'https://www.magazine-data.com/cover/popteen.html',
#  'https://www.magazine-data.com/cover/seventeen.html',
#  'https://www.magazine-data.com/cover/cancam.html',
#  'https://www.magazine-data.com/cover/vivi.html',
#  'https://www.magazine-data.com/cover/ray.html',
#  'https://www.magazine-data.com/cover/jj.html',
#  'https://www.magazine-data.com/cover/ar.html',
#  'https://www.magazine-data.com/cover/mini.html',
#  'https://www.magazine-data.com/cover/mina.html',
#  'https://www.magazine-data.com/cover/with.html',
#  'https://www.magazine-data.com/cover/more.html',
#  'https://www.magazine-data.com/cover/sweet.html',
#  'https://www.magazine-data.com/cover/steady.html',
#  'https://www.magazine-data.com/cover/spring.html',
#  'https://www.magazine-data.com/cover/ginger.html',
#  'https://www.magazine-data.com/cover/andgirl.html',
#  'https://www.magazine-data.com/cover/bijinhyakka.html',
#  'https://www.magazine-data.com/cover/oggi.html',
#  'https://www.magazine-data.com/cover/baila.html',
#  'https://www.magazine-data.com/cover/marisol.html',
#  'https://www.magazine-data.com/cover/lee.html',
#  'https://www.magazine-data.com/cover/inred.html',
#  'https://www.magazine-data.com/cover/glow.html',
#  'https://www.magazine-data.com/cover/liniere.html',
#  'https://www.magazine-data.com/cover/otonanoosyaretecho.html',
#  'https://www.magazine-data.com/cover/nylonjapan.html',
#  'https://www.magazine-data.com/cover/nylonjapanguys.html',
#  'https://www.magazine-data.com/cover/numerotokyo.html',
#  'https://www.magazine-data.com/cover/nicola.html',
#  'https://www.magazine-data.com/cover/souen.html',
#  'https://www.magazine-data.com/cover/bis.html',
#  'https://www.magazine-data.com/cover/jelly.html',
#  'https://www.magazine-data.com/cover/larme.html',
#  'https://www.magazine-data.com/cover/shethree.html',
#  'https://www.magazine-data.com/cover/gina.html',
#  'https://www.magazine-data.com/cover/mrs.html',
#  'https://www.magazine-data.com/cover/esse.html',
#  'https://www.magazine-data.com/cover/bistory.html',
#  'https://www.magazine-data.com/cover/biteki.html',
#  'https://www.magazine-data.com/cover/voce.html',
#  'https://www.magazine-data.com/cover/maquia.html',
#  'https://www.magazine-data.com/cover/upplus.html',
#  'https://www.magazine-data.com/cover/scawaii.html',
#  'https://www.magazine-data.com/cover/nikkeiwomen.html',
#  'https://www.magazine-data.com/cover/hanako.html',
#  'https://www.magazine-data.com/cover/neko.html',
#  'https://www.magazine-data.com/cover/mensnonno.html',
#  'https://www.magazine-data.com/cover/fineboys.html',
#  'https://www.magazine-data.com/cover/smart.html',
#  'https://www.magazine-data.com/cover/fine.html',
#  'https://www.magazine-data.com/cover/uomo.html',
#  'https://www.magazine-data.com/cover/gqjapan.html',
#  'https://www.magazine-data.com/cover/tokyocalendar.html',
#  'https://www.magazine-data.com/cover/menspreppy.html',
#  'https://www.magazine-data.com/cover/myojo.html',
#  'https://www.magazine-data.com/cover/duet.html',
#  'https://www.magazine-data.com/cover/winkup.html',
#  'https://www.magazine-data.com/cover/potato.html',
#  'https://www.magazine-data.com/cover/qlap.html',
#  'https://www.magazine-data.com/cover/tvguideperson.html',
#  'https://www.magazine-data.com/cover/jmoviemagazine.html',
#  'https://www.magazine-data.com/cover/cinemasquare.html',
#  'https://www.magazine-data.com/cover/stagenavi.html',
#  'https://www.magazine-data.com/cover/beststage.html',
#  'https://www.magazine-data.com/cover/stagesquare.html',
#  'https://www.magazine-data.com/cover/dancesquare.html',
#  'https://www.magazine-data.com/cover/barfout.html',
#  'https://www.magazine-data.com/cover/soda.html',
#  'https://www.magazine-data.com/cover/cluster.html',
#  'https://www.magazine-data.com/cover/plusact.html',
#  'https://www.magazine-data.com/cover/awesome.html',
#  'https://www.magazine-data.com/cover/tvguide.html',
#  'https://www.magazine-data.com/cover/thetelevision.html',
#  'https://www.magazine-data.com/cover/tvlife.html',
#  'https://www.magazine-data.com/cover/tvguidemonthly.html',
#  'https://www.magazine-data.com/cover/thetelevisionmonthly.html',
#  'https://www.magazine-data.com/cover/nikkeientertainment.html',
#  'https://www.magazine-data.com/cover/cut.html',
#  'https://www.magazine-data.com/cover/blt.html',
#  'https://www.magazine-data.com/cover/bomb.html',
#  'https://www.magazine-data.com/cover/bubka.html',
#  'https://www.magazine-data.com/cover/entame.html',
#  'https://www.magazine-data.com/cover/extaishu.html',
#  'https://www.magazine-data.com/cover/uptoboy.html',
#  'https://www.magazine-data.com/cover/bltgraph.html',
#  'https://www.magazine-data.com/cover/brody.html',
#  'https://www.magazine-data.com/cover/bigonegirls.html',
#  'https://www.magazine-data.com/cover/seiyuanimedia.html',
#  'https://www.magazine-data.com/cover/seiyuguranpuri.html',
#  'https://www.magazine-data.com/cover/playboy.html',
#  'https://www.magazine-data.com/cover/weeklyasahi.html',
#  'https://www.magazine-data.com/cover/aera.html',
#  'https://www.magazine-data.com/cover/capa.html',
#  'https://www.magazine-data.com/cover/macfan.html',
#  'https://www.magazine-data.com/cover/yaseijidai.html',
#  'https://www.magazine-data.com/cover/davinci.html',
#  'https://www.magazine-data.com/cover/laidback.html',
#  'https://www.magazine-data.com/cover/walker.html',
#  'https://www.magazine-data.com/cover/chanto.html',
#  'https://www.magazine-data.com/cover/clubism.html',
#  'https://www.magazine-data.com/cover/tvbros.html',
#  'https://www.magazine-data.com/cover/cameraman.html',
#  'https://www.magazine-data.com/cover/auditionblue.html']

# %%
len(cover_urls)
# Out:
# 105

# %% [markdown]
# 雑誌は全部で105件

# %%
# 特定の雑誌情報の取得
df = get_magazine_summary(cover_urls[0])
df
# Out:
#              巻号           モデル  \
# 0   2021年 3/10号         菊池 風磨
# 1    2021年 3/3号         日向坂46
# 2   2021年 2/24号  岩田 剛典・新田 真剣佑
# 3   2021年 2/17号         松村 北斗
# 4   2021年 2/10号         玉森 裕太
# ..          ...           ...
# 95   2019年 3/6号         増田 貴久
# 96  2019年 2/27号       KAT-TUN
# 97  2019年 2/20号         高木 雄也
# 98  2019年 2/13号         登坂 広臣
# 99   2019年 2/6号        生田 絵梨花
#
#                                                   URL         発売日    雑誌名  \
# 0   https://www.magazine-data.com/page/20210303ana...   2021年3月3日  an・an
# 1   https://www.magazine-data.com/page/20210224ana...  2021年2月24日  an・an
# 2   https://www.magazine-data.com/page/20210217ana...  2021年2月17日  an・an
# 3   https://www.magazine-data.com/page/20210210ana...  2021年2月10日  an・an
# 4   https://www.magazine-data.com/page/20210203ana...   2021年2月3日  an・an
# ..                                                ...         ...    ...
# 95      https://www.magazine-data.com/cover/anan.html  2019年2月27日  an・an
# 96      https://www.magazine-data.com/cover/anan.html  2019年2月20日  an・an
# 97      https://www.magazine-data.com/cover/anan.html  2019年2月13日  an・an
# 98      https://www.magazine-data.com/cover/anan.html   2019年2月6日  an・an
# 99      https://www.magazine-data.com/cover/anan.html  2019年1月30日  an・an
#
#     ザッシ名     年  月
# 0   アンアン  2021  3
# 1   アンアン  2021  2
# 2   アンアン  2021  2
# 3   アンアン  2021  2
# 4   アンアン  2021  2
# ..   ...   ... ..
# 95  アンアン  2019  2
# 96  アンアン  2019  2
# 97  アンアン  2019  2
# 98  アンアン  2019  2
# 99  アンアン  2019  1
#
# [100 rows x 8 columns]

# %%
# 全雑誌情報の取得
# sleep内に指定した時間×雑誌数くらいの時間がかかります。
for i, url in enumerate(cover_urls):
    if i == 0:
        df = get_magazine_summary(url)
    else:
        df = pd.concat([df, get_magazine_summary(url)])
    time.sleep(2) # サイトに負荷をかけないように2秒待つ。少なくとも1秒以上に設定してください。

# %%
df
# Out:
#                巻号           モデル  \
# 0     2021年 3/10号         菊池 風磨
# 1      2021年 3/3号         日向坂46
# 2     2021年 2/24号  岩田 剛典・新田 真剣佑
# 3     2021年 2/17号         松村 北斗
# 4     2021年 2/10号         玉森 裕太
# ..            ...           ...
# 17  blue 2019年5月号          吉沢 亮
# 18  blue 2019年4月号         片寄 涼太
# 19  blue 2019年3月号        新田 真剣佑
# 20  blue 2019年2月号  BOYS AND MEN
# 21  blue 2019年1月号          田中 圭
#
#                                                   URL          発売日       雑誌名  \
# 0   https://www.magazine-data.com/page/20210303ana...    2021年3月3日     an・an
# 1   https://www.magazine-data.com/page/20210224ana...   2021年2月24日     an・an
# 2   https://www.magazine-data.com/page/20210217ana...   2021年2月17日     an・an
# 3   https://www.magazine-data.com/page/20210210ana...   2021年2月10日     an・an
# 4   https://www.magazine-data.com/page/20210203ana...    2021年2月3日     an・an
# ..                                                ...          ...       ...
# 17  https://www.magazine-data.com/cover/auditionbl...    2019年4月1日  Audition
# 18  https://www.magazine-data.com/cover/auditionbl...    2019年3月1日  Audition
# 19  https://www.magazine-data.com/cover/auditionbl...    2019年2月1日  Audition
# 20  https://www.magazine-data.com/cover/auditionbl...  2018年12月29日  Audition
# 21  https://www.magazine-data.com/cover/auditionbl...   2018年12月1日  Audition
#
#         ザッシ名     年   月
# 0       アンアン  2021   3
# 1       アンアン  2021   2
# 2       アンアン  2021   2
# 3       アンアン  2021   2
# 4       アンアン  2021   2
# ..       ...   ...  ..
# 17  Audition  2019   4
# 18  Audition  2019   3
# 19  Audition  2019   2
# 20  Audition  2018  12
# 21  Audition  2018  12
#
# [3030 rows x 8 columns]

# %%
df["モデル"].value_counts()
# Out:
# King & Prince     64
# SixTONES          61
# Snow Man          57
# 嵐                 38
# ジャニーズ WEST        30
#                   ..
# ラブライブ!サンシャイン!!     1
# 諏訪 ななか             1
# 山﨑 天               1
# 与田 祐希・ 山下 美月       1
# 長澤 まさみ・東出 昌大       1
# Name: モデル, Length: 916, dtype: int64

# %%
df[df["年"]==2021]["モデル"].value_counts()
# Out:
# 松村 北斗                9
# Snow Man             9
# SixTONES             6
# 亀梨 和也                5
# 玉森 裕太                4
#                     ..
# 滝沢 カレン               1
# 石原 さとみ               1
# トリンドル 玲奈・トリンドル 瑠奈    1
# 桐谷 美玲                1
# 茅野 愛衣                1
# Name: モデル, Length: 166, dtype: int64

# %%
df.to_csv("210225_analyze_magazine_cover.csv", index=False)
